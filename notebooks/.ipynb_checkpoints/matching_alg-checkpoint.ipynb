# %%
import pandas as pd

# ---------- SETTINGS ----------
# Zet hier de bestandsnamen van je CSV's
MENTOREN_FILE = "../data/mentoren.csv"
STUDENTEN_FILE = "../data/studenten.csv"
OUTPUT_FILE = "../output/matches.csv"

# ---------- DATA INLADEN ----------
mentoren_df = pd.read_csv(MENTOREN_FILE)
studenten_df = pd.read_csv(STUDENTEN_FILE)

# Zorg dat onderwerpen correct als lijst worden gelezen
mentoren_df["Onderwerpen"] = mentoren_df["Onderwerpen"].apply(
    lambda x: eval(x) if isinstance(x, str) and x.startswith("[") else [x]
)

# Opleidingsniveaus ordenen
level_order = {"Associate": 0, "Bachelor": 1, "Master": 2, "PhD": 3}

# ---------- MATCHING FUNCTIE ----------
def find_best_mentor(student, mentoren_df):
    student_level = level_order.get(student["Opleidingsniveau"], -1)
    student_subject = student["Onderwerp"]

    best_match = None
    best_score = -1

    for _, mentor in mentoren_df.iterrows():
        mentor_level = level_order.get(mentor["Opleidingsniveau"], -1)

        # Mentor moet hoger niveau hebben
        if mentor_level <= student_level:
            continue

        # Onderwerp match
        subject_match = 1 if student_subject in mentor["Onderwerpen"] else 0

        # Score = niveauverschil + extra punten voor onderwerp
        score = (mentor_level - student_level) + (subject_match * 2)

        if score > best_score:
            best_score = score
            best_match = mentor

    if best_match is not None:
        return {
            "Student": f"{student['Voornaam']} {student['Achternaam']}",
            "Student_niveau": student["Opleidingsniveau"],
            "Onderwerp": student_subject,
            "Mentor": f"{best_match['Voornaam']} {best_match['Achternaam']}",
            "Mentor_niveau": best_match["Opleidingsniveau"],
            "Mentor_onderwerpen": best_match["Onderwerpen"],
            "Match_score": best_score,
        }
    else:
        return {
            "Student": f"{student['Voornaam']} {student['Achternaam']}",
            "Student_niveau": student["Opleidingsniveau"],
            "Onderwerp": student_subject,
            "Mentor": None,
            "Mentor_niveau": None,
            "Mentor_onderwerpen": None,
            "Match_score": 0,
        }

# ---------- MATCHES MAKEN ----------
matches = [find_best_mentor(student, mentoren_df) for _, student in studenten_df.iterrows()]
matches_df = pd.DataFrame(matches)

# ---------- RESULTAAT OPSLAAN ----------
matches_df.to_csv(OUTPUT_FILE, index=False)
print(f"Matching voltooid! Resultaat opgeslagen in {OUTPUT_FILE}")
# Out:
# Matching voltooid! Resultaat opgeslagen in ../output/matches.csv

# %%
import random
import pandas as pd


class Student:
    def __init__(self, naam: str, niveau: str, onderwerp: str):
        self.naam = naam
        self.niveau = niveau
        self.onderwerp = onderwerp

    def __repr__(self):
        return f"Student(naam={self.naam}, niveau={self.niveau}, onderwerp={self.onderwerp})"

class Mentor:
    def __init__(self, naam: str, niveau: str, onderwerpen: list[str], max_studenten: int):
        self.naam = naam
        self.niveau = niveau
        self.onderwerpen = onderwerpen
        self.max_studenten = max_studenten

    def __repr__(self):
        return f"Mentor(naam={self.naam}, niveau={self.niveau}, onderwerpen={self.onderwerpen}, max_studenten={self.max_studenten})"
    

def vul_studenten(studenten_lijst, csv_path, n):
    df = pd.read_csv(csv_path)
    rows = df.sample(n=min(n, len(df)))
    for _, row in rows.iterrows():
        naam = f"{row['Voornaam']} {row['Achternaam']}" if 'Voornaam' in row and 'Achternaam' in row else row.get('Naam', '')
        studenten_lijst.append(Student(naam, row['Opleidingsniveau'], row['Onderwerp']))


def vul_mentoren(mentoren_lijst, csv_path, n):
    df = pd.read_csv(csv_path)
    # Zorg dat onderwerpen als lijst worden gelezen
    df["Onderwerpen"] = df["Onderwerpen"].apply(lambda x: eval(x) if isinstance(x, str) and x.startswith("[") else [x])
    rows = df.sample(n=min(n, len(df)))
    for _, row in rows.iterrows():
        naam = f"{row['Voornaam']} {row['Achternaam']}" if 'Voornaam' in row and 'Achternaam' in row else row.get('Naam', '')
        max_studenten = random.randint(1, 5)
        mentoren_lijst.append(Mentor(naam, row['Opleidingsniveau'], row['Onderwerpen'], max_studenten))


studenten = []
mentoren = []

vul_studenten(studenten, "../data/studenten.csv", 90)
vul_mentoren(mentoren, "../data/mentoren.csv", 30)

print(studenten)
print(mentoren)
# Out:
# [Student(naam=Seth Molegraaf, niveau=Associate, onderwerp=Business Change and Innovation), Student(naam=Roos Schiffer, niveau=Associate, onderwerp=Business Process Analytics), Student(naam=Naud Kleijse, niveau=Associate, onderwerp=Software Architecture), Student(naam=Isabelle van de Elzas, niveau=Bachelor, onderwerp=Design Science Research), Student(naam=Tyler Miltenburg, niveau=Bachelor, onderwerp=Business Process Analytics), Student(naam=Nick Kolster, niveau=Bachelor, onderwerp=Design Science Research), Student(naam=Felix Olykan, niveau=Associate, onderwerp=Business Change and Innovation), Student(naam=Seth Groenestein, niveau=Associate, onderwerp=Business Process Analytics), Student(naam=Tristan Kruns, niveau=Associate, onderwerp=Business Process Analytics), Student(naam=Emir Jorrisen, niveau=Bachelor, onderwerp=Artificial Intelligence), Student(naam=Nynke Verbeeck, niveau=Bachelor, onderwerp=Data Visualisation), Student(naam=Leah van 't Riet, niveau=Bachelor, onderwerp=Ethical Hacking), Student(naam=Kyano de Bruin, niveau=Bachelor, onderwerp=Software Architecture), Student(naam=Jesper van Velzen, niveau=Associate, onderwerp=Business Change and Innovation), Student(naam=Sep Molen, niveau=Associate, onderwerp=Data Science), Student(naam=Tim Winters, niveau=Bachelor, onderwerp=Data Visualisation), Student(naam=Ivan van Bentheim, niveau=Bachelor, onderwerp=Ethical Hacking), Student(naam=Milou Vertoor, niveau=Bachelor, onderwerp=Data Science), Student(naam=Jacob van den Henst, niveau=Bachelor, onderwerp=Data Science), Student(naam=Floris ter Waarbeek, niveau=Bachelor, onderwerp=Software Architecture), Student(naam=Amin de Lange, niveau=Associate, onderwerp=Business Process Analytics), Student(naam=Aaron van de Wal, niveau=Associate, onderwerp=Business Change and Innovation), Student(naam=Mason van der Horst, niveau=Associate, onderwerp=Data Science), Student(naam=Roan Passchiers, niveau=Associate, onderwerp=Business Change and Innovation), Student(naam=Eva Simonis, niveau=Bachelor, onderwerp=Software Architecture), Student(naam=Collin Huisman, niveau=Associate, onderwerp=Design Science Research), Student(naam=David Bronder, niveau=Associate, onderwerp=Design Science Research), Student(naam=Noortje Kuijpers, niveau=Bachelor, onderwerp=Business Process Analytics), Student(naam=Jennifer van de Greef, niveau=Bachelor, onderwerp=Business Process Analytics), Student(naam=Dion van den Corput, niveau=Bachelor, onderwerp=Data Visualisation), Student(naam=Arie Charon, niveau=Bachelor, onderwerp=Business Process Analytics), Student(naam=Lieve Mudden, niveau=Associate, onderwerp=Design Science Research), Student(naam=Tessa Molen, niveau=Associate, onderwerp=Creative Digital Innovation), Student(naam=Dean Holthuis, niveau=Associate, onderwerp=Business Change and Innovation), Student(naam=Dina van Maaren, niveau=Associate, onderwerp=Data Visualisation), Student(naam=Ravi Cosman, niveau=Bachelor, onderwerp=Business Change and Innovation), Student(naam=Esther Scholten, niveau=Associate, onderwerp=Data Visualisation), Student(naam=Damian Gnodde, niveau=Bachelor, onderwerp=Ethical Hacking), Student(naam=Rosalie Segerszoen, niveau=Associate, onderwerp=Data Science), Student(naam=Bram Marceron, niveau=Associate, onderwerp=Data Visualisation), Student(naam=Maja Fortuyn, niveau=Bachelor, onderwerp=Design Science Research), Student(naam=Lisa de Swart, niveau=Bachelor, onderwerp=Software Architecture), Student(naam=Floor Merkx, niveau=Bachelor, onderwerp=Artificial Intelligence), Student(naam=Jip van Wessex, niveau=Associate, onderwerp=Data Visualisation), Student(naam=Arthur Jacobi, niveau=Associate, onderwerp=Creative Digital Innovation), Student(naam=Micha Claesdr, niveau=Bachelor, onderwerp=Creative Digital Innovation), Student(naam=Bryan Maas, niveau=Associate, onderwerp=Artificial Intelligence), Student(naam=Adriana Pieters van der Maes, niveau=Associate, onderwerp=Ethical Hacking), Student(naam=Dewi Houdijk, niveau=Bachelor, onderwerp=Ethical H ...
# [Mentor(naam=Nout Brumleve, niveau=Master, onderwerpen=['Data Visualisation', 'Business Change and Innovation', 'Creative Digital Innovation', 'Business Process Analytics'], max_studenten=2), Mentor(naam=Yinthe van Dagsburg, niveau=Master, onderwerpen=['Ethical Hacking', 'Artificial Intelligence'], max_studenten=2), Mentor(naam=Vigo van 't Wel, niveau=Bachelor, onderwerpen=['Artificial Intelligence', 'Software Architecture'], max_studenten=4), Mentor(naam=Luka Sanders, niveau=PhD, onderwerpen=['Business Process Analytics', 'Business Change and Innovation', 'Data Science'], max_studenten=4), Mentor(naam=Dana van de Pol, niveau=PhD, onderwerpen=['Ethical Hacking', 'Business Change and Innovation'], max_studenten=1), Mentor(naam=Adriana Schelvis, niveau=Master, onderwerpen=['Ethical Hacking', 'Creative Digital Innovation', 'Artificial Intelligence', 'Software Architecture'], max_studenten=3), Mentor(naam=Jill Jans, niveau=Master, onderwerpen=['Software Architecture', 'Ethical Hacking', 'Creative Digital Innovation', 'Data Visualisation'], max_studenten=4), Mentor(naam=Jayda Mulders, niveau=Bachelor, onderwerpen=['Ethical Hacking', 'Design Science Research', 'Data Visualisation', 'Data Science'], max_studenten=5), Mentor(naam=Lize van der Schuijt, niveau=Bachelor, onderwerpen=['Data Science', 'Software Architecture', 'Design Science Research'], max_studenten=1), Mentor(naam=Amélie Garret, niveau=PhD, onderwerpen=['Artificial Intelligence', 'Creative Digital Innovation'], max_studenten=4), Mentor(naam=Luke Mosley, niveau=Bachelor, onderwerpen=['Data Science', 'Artificial Intelligence', 'Design Science Research'], max_studenten=2), Mentor(naam=Amelia van der Strigt, niveau=Bachelor, onderwerpen=['Creative Digital Innovation', 'Business Change and Innovation', 'Software Architecture', 'Artificial Intelligence'], max_studenten=4), Mentor(naam=Hailey Coenen, niveau=PhD, onderwerpen=['Software Architecture', 'Data Visualisation', 'Creative Digital Innovation', 'Business Change and Innovation'], max_studenten=5), Mentor(naam=Thijs van Waas, niveau=PhD, onderwerpen=['Software Architecture', 'Data Science', 'Business Change and Innovation'], max_studenten=5), Mentor(naam=Amelia van den Hoek, niveau=Master, onderwerpen=['Business Process Analytics', 'Artificial Intelligence', 'Software Architecture'], max_studenten=5), Mentor(naam=Bart van Haspengouw, niveau=Master, onderwerpen=['Artificial Intelligence', 'Ethical Hacking', 'Software Architecture', 'Creative Digital Innovation'], max_studenten=4), Mentor(naam=Senna van den Eerenbeemt, niveau=Master, onderwerpen=['Business Process Analytics', 'Artificial Intelligence', 'Design Science Research'], max_studenten=5), Mentor(naam=Ivan den Teuling, niveau=Master, onderwerpen=['Creative Digital Innovation', 'Business Process Analytics', 'Data Visualisation', 'Data Science'], max_studenten=4), Mentor(naam=Chris van Landen, niveau=PhD, onderwerpen=['Data Visualisation', 'Ethical Hacking'], max_studenten=3), Mentor(naam=Lois van Baalen, niveau=Bachelor, onderwerpen=['Business Process Analytics', 'Software Architecture', 'Business Change and Innovation'], max_studenten=2), Mentor(naam=Beau van Spreuwel, niveau=Master, onderwerpen=['Data Visualisation', 'Software Architecture'], max_studenten=1), Mentor(naam=Mick Verschut, niveau=Bachelor, onderwerpen=['Creative Digital Innovation', 'Data Visualisation', 'Business Process Analytics', 'Design Science Research'], max_studenten=2), Mentor(naam=Charlotte Pieters, niveau=Bachelor, onderwerpen=['Data Science', 'Design Science Research', 'Data Visualisation', 'Ethical Hacking'], max_studenten=5), Mentor(naam=Mick Verhoeven, niveau=Master, onderwerpen=['Ethical Hacking', 'Creative Digital Innovation'], max_studenten=4), Mentor(naam=Xavi van Wickerode, niveau=Master, onderwerpen=['Ethical Hacking', 'Data Visualisation', 'Software Architecture', 'Business Process Analytics'], max_studenten=1), Mentor(naam=Pippa Koret, niveau=PhD, onderwerpen=['Software Architect ...

# %%
from collections import deque
import copy

def bfs_student_mentor_matching(studenten, mentoren):
    # Prepare mentor slots
    mentor_slots = {i: mentoren[i].max_studenten for i in range(len(mentoren))}
    # State: (student_index, current_assignment, mentor_slots)
    # current_assignment: list of mentor indices (or None) for each student
    initial_state = (0, [], mentor_slots)
    queue = deque([initial_state])

    while queue:
        student_idx, assignment, slots = queue.popleft()
        if student_idx == len(studenten):
            # All students assigned
            return assignment

        student = studenten[student_idx]
        assigned = False
        # Try all mentors
        for mentor_idx, mentor in enumerate(mentoren):
            if (
                mentor_slots[mentor_idx] > 0
                and student.onderwerp in mentor.onderwerpen
                and level_order[mentor.niveau] > level_order[student.niveau]
            ):
                # Copy slots for next state
                new_slots = copy.deepcopy(slots)
                new_slots[mentor_idx] -= 1
                queue.append((student_idx + 1, assignment + [mentor_idx], new_slots))
                assigned = True
        # Also allow no assignment (if no mentor fits)
        if not assigned:
            queue.append((student_idx + 1, assignment + [None], slots))
    return None  # No solution found

# Voorbeeld van gebruik:
result = bfs_student_mentor_matching(studenten, mentoren)
for idx, mentor_idx in enumerate(result):
    student = studenten[idx]
    mentor = mentoren[mentor_idx] if mentor_idx is not None else None
    print(f"{student.naam} -> {mentor.naam if mentor else 'GEEN MATCH'}")
